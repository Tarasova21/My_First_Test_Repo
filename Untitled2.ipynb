# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarasova21/My_First_Test_Repo/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown Пример использования Markdown
#@markdown 
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %% [markdown]
# 1. Велосипед
# 1. Ролики
# 1. Скейтборд

# %% [markdown]
# | A | B | C |
#     |---|---|---|
#     | 10 | 5 | 2 |
#     | 3 | 4 | 8 |

# %% [markdown]
# https://vk.com/vsemprivetdruzya
